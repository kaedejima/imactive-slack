# %%
import cv2
from datetime import datetime
import dlib
from imutils import face_utils
import imutils

import subprocess
import os
from dotenv import load_dotenv
import requests
from datetime import date
import json
import time
import datetime
import pandas as pd
import numpy as np

from slack import WebClient

load_dotenv()

slack_oauth_token = os.environ['SLACK_OAUTH_TOKEN']
slack_user_token = os.environ['SLACK_USER_TOKEN']
user_id = os.environ['USER_ID']

face_detector = dlib.get_frontal_face_detector()
predictor_path = 'shape_predictor_68_face_landmarks.dat'
face_predictor = dlib.shape_predictor(predictor_path)

# %%
class SlackDriver:
    def __init__(self, _oauth_token, _user_token):
        self._oauth_token = _oauth_token  # api_token
        self._user_token = _user_token
        self._headers = {'Content-Type': 'application/json'}

    def send_message(self, message, channel):
        params = {"token": self._user_token,
                  "channel": channel, "text": message}

        r = requests.post('https://slack.com/api/chat.postMessage',
                          headers=self._headers, params=params)

        # print(r.text)

    def change_status(self, text, emoji):
        params = {
            "token": self._oauth_token,
            # "user": user_id,
            "profile": json.dumps({
                "status_text": text,
                "status_emoji": emoji
            })
        }
        # print(params)

        r = requests.post(
            'https://slack.com/api/users.profile.set', params=params)
        # print(r.text)

    def send_button(self):
        callback_id = 'status_show_all'
        attachments = [{
            'text': 'Show status of ...',
            'callback_id': callback_id,
            'color': '#EE2222',
            'attachment_type': 'default',
            'actions': [{
                'name': 'all',
                'text': 'ALL',
                'type': 'button'
            },
                {
                'name': 'self',
                'text': 'YOU',
                'type': 'button'
            }]
        }]

        element_user_selector = {
            "type": "section",
            "text": {
                "type": "mrkdwn",
                "text": "Which user do you want to check?"
            },
            "accessory": {
                "type": "users_select",
                "placeholder": {
                    "type": "plain_text",
                    "text": "Select a user",
                },
                "action_id": "users_select-action"
            },
        }
        element_button = {
            "type": "actions",
            "elements": [
                {
                    "type": "button",
                    "text": {
                        "type": "plain_text",
                        "text": "Show All Status"
                    },
                    "value": "show_all",
                    "action_id": "button"
                }]
        }
        blocks = [element_button, element_user_selector]

        data = {
            'token': self._user_token,
            'channel': 'C01CRGA8QK0',
            'username': 'me',
            'blocks': json.dumps(blocks)
            # 'attachments': json.dumps(attachments)
        }

        r = requests.post(
            'https://slack.com/api/chat.postMessage', params=data)
        print(r.text)

    def read_presence(self, user):
        params = {"token": self._user_token, "user":user}
        r = requests.post('https://slack.com/api/users.getPresence',
                          headers=self._headers, params=params)
        # print(r.text)
        return r.json()

    def users_list(self):
        params = {"token": self._user_token}
        r = requests.post('	https://slack.com/api/users.list',
                          headers=self._headers, params=params)

        rjson = r.json()
        # print(rjson)
        # presence_str = ''
        member_list = []
        for i in range(0, len(rjson["members"])):  # range(0, #of menbers)
            # print(rjson["members"][i]["id"])
            member_list.append(rjson["members"][i]["id"])
        return member_list
        # #     presence = self.read_presence(rjson["members"][i]["id"])
        # #     presence_str += str(rjson["members"][i]["name"]) + ' is ' + str(presence["presence"]) + '\n'
        # # self.send_message(presence_str,'#imactive-response')
        # for member_id in member_list:
        #     res = self.read_presence(member_id)
        #     print(res)

    def track_presence(self, member_list):
        start_time = datetime.datetime.now()
        print(start_time)
        seconds = 3
        col = ['Time']+member_list
        df = pd.DataFrame(columns=col)
        curr_dict = {s: {'status':'away', 'last_modified': start_time} for s in member_list}
        print(col)
        tmp_flag = False

        while True:
            current_time = datetime.datetime.now()
            elapsed_time = current_time - start_time
            print(elapsed_time)
            # if elapsed_time > seconds:
            start_time = datetime.datetime.now()
            res_list = [current_time]
            for member_id in member_list:
                current_status = self.read_presence(member_id)['presence']
                res_list.append(current_status)
                print('current_status[]', current_status)
                print('curr_dict[member_id][\'status\']', curr_dict[member_id]['status'])
                if(curr_dict[member_id]['status'] == current_status):
                    print('changed!')
                    curr_dict[member_id]['status'] = current_status
                    curr_dict[member_id]['last_modified'] = start_time
            print('reslist',res_list)
            df.loc[len(df)] = res_list
            # print(res_list)
            print(curr_dict)
            print(df)
            if len(df) > 11:
                df = df.drop(df.index[[0]])
                df.reset_index(drop=True,inplace=True)
            time.sleep(seconds)
        return df

# %%
slack = SlackDriver(slack_oauth_token, slack_user_token)
# slack.send_button()
member_list = slack.users_list()

# %%
list_df = slack.track_presence(member_list)
# Out:
# 2020-12-09 21:34:40.414826
# ['Time', 'USLACKBOT', 'UFP3UKJ2G', 'UTASCHNN9', 'UTASDEA1K', 'U01DN3G99HN']
# 0:00:00.014835
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] active
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# reslist [datetime.datetime(2020, 12, 9, 21, 34, 40, 429661), 'away', 'active', 'away', 'away', 'away']
# {'USLACKBOT': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 40, 436033)}, 'UFP3UKJ2G': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 40, 414826)}, 'UTASCHNN9': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 40, 436033)}, 'UTASDEA1K': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 40, 436033)}, 'U01DN3G99HN': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 40, 436033)}}
#                         Time USLACKBOT UFP3UKJ2G UTASCHNN9 UTASDEA1K  \
# 0 2020-12-09 21:34:40.429661      away    active      away      away
#
#   U01DN3G99HN
# 0        away
# 0:00:06.868358
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] active
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# reslist [datetime.datetime(2020, 12, 9, 21, 34, 47, 304391), 'away', 'active', 'away', 'away', 'away']
# {'USLACKBOT': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 47, 304534)}, 'UFP3UKJ2G': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 40, 414826)}, 'UTASCHNN9': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 47, 304534)}, 'UTASDEA1K': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 47, 304534)}, 'U01DN3G99HN': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 47, 304534)}}
#                         Time USLACKBOT UFP3UKJ2G UTASCHNN9 UTASDEA1K  \
# 0 2020-12-09 21:34:40.429661      away    active      away      away
# 1 2020-12-09 21:34:47.304391      away    active      away      away
#
#   U01DN3G99HN
# 0        away
# 1        away
# 0:00:05.926177
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# reslist [datetime.datetime(2020, 12, 9, 21, 34, 53, 230711), 'away', 'away', 'away', 'away', 'away']
# {'USLACKBOT': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 53, 231967)}, 'UFP3UKJ2G': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 53, 231967)}, 'UTASCHNN9': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 53, 231967)}, 'UTASDEA1K': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 53, 231967)}, 'U01DN3G99HN': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 34, 53, 231967)}}
#                         Time USLACKBOT UFP3UKJ2G UTASCHNN9 UTASDEA1K  \
# 0 2020-12-09 21:34:40.429661      away    active      away      away
# 1 2020-12-09 21:34:47.304391      away    active      away      away
# 2 2020-12-09 21:34:53.230711      away      away      away      away
#
#   U01DN3G99HN
# 0        away
# 1        away
# 2        away
# 0:00:07.692951
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# reslist [datetime.datetime(2020, 12, 9, 21, 35, 0, 924918), 'away', 'away', 'away', 'away', 'away']
# {'USLACKBOT': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 0, 925767)}, 'UFP3UKJ2G': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 0, 925767)}, 'UTASCHNN9': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 0, 925767)}, 'UTASDEA1K': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 0, 925767)}, 'U01DN3G99HN': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 0, 925767)}}
#                         Time USLACKBOT UFP3UKJ2G UTASCHNN9 UTASDEA1K  \
# 0 2020-12-09 21:34:40.429661      away    active      away      away
# 1 2020-12-09 21:34:47.304391      away    active      away      away
# 2 2020-12-09 21:34:53.230711      away      away      away      away
# 3 2020-12-09 21:35:00.924918      away      away      away      away
#
#   U01DN3G99HN
# 0        away
# 1        away
# 2        away
# 3        away
# 0:00:06.551976
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# reslist [datetime.datetime(2020, 12, 9, 21, 35, 7, 477743), 'away', 'away', 'away', 'away', 'away']
# {'USLACKBOT': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 7, 479025)}, 'UFP3UKJ2G': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 7, 479025)}, 'UTASCHNN9': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 7, 479025)}, 'UTASDEA1K': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 7, 479025)}, 'U01DN3G99HN': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 7, 479025)}}
#                         Time USLACKBOT UFP3UKJ2G UTASCHNN9 UTASDEA1K  \
# 0 2020-12-09 21:34:40.429661      away    active      away      away
# 1 2020-12-09 21:34:47.304391      away    active      away      away
# 2 2020-12-09 21:34:53.230711      away      away      away      away
# 3 2020-12-09 21:35:00.924918      away      away      away      away
# 4 2020-12-09 21:35:07.477743      away      away      away      away
#
#   U01DN3G99HN
# 0        away
# 1        away
# 2        away
# 3        away
# 4        away
# 0:00:07.684307
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# reslist [datetime.datetime(2020, 12, 9, 21, 35, 15, 163332), 'away', 'away', 'away', 'away', 'away']
# {'USLACKBOT': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 15, 164701)}, 'UFP3UKJ2G': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 15, 164701)}, 'UTASCHNN9': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 15, 164701)}, 'UTASDEA1K': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 15, 164701)}, 'U01DN3G99HN': {'status': 'away', 'last_modified': datetime.datetime(2020, 12, 9, 21, 35, 15, 164701)}}
#                         Time USLACKBOT UFP3UKJ2G UTASCHNN9 UTASDEA1K  \
# 0 2020-12-09 21:34:40.429661      away    active      away      away
# 1 2020-12-09 21:34:47.304391      away    active      away      away
# 2 2020-12-09 21:34:53.230711      away      away      away      away
# 3 2020-12-09 21:35:00.924918      away      away      away      away
# 4 2020-12-09 21:35:07.477743      away      away      away      away
# 5 2020-12-09 21:35:15.163332      away      away      away      away
#
#   U01DN3G99HN
# 0        away
# 1        away
# 2        away
# 3        away
# 4        away
# 5        away
# 0:00:07.061970
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# current_status[] away
# curr_dict[member_id]['status'] away
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-146-f404610ce5a4> in <module>
# ----> 1 list_df = slack.track_presence(member_list)
#
# <ipython-input-144-4c65fc4a458a> in track_presence(self, member_list)
#     135             res_list = [current_time]
#     136             for member_id in member_list:
# --> 137                 current_status = self.read_presence(member_id)['presence']
#     138                 res_list.append(current_status)
#     139                 print('current_status[]', current_status)
#
# <ipython-input-144-4c65fc4a458a> in read_presence(self, user)
#      92     def read_presence(self, user):
#      93         params = {"token": self._user_token, "user":user}
# ---> 94         r = requests.post('https://slack.com/api/users.getPresence',
#      95                           headers=self._headers, params=params)
#      96         # print(r.text)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
new_df = list_df
print(new_df)
# Out:
#                          Time USLACKBOT UFP3UKJ2G UTASCHNN9 UTASDEA1K  \
# 0  2020-12-09 19:28:42.642784      away    active      away      away
# 1  2020-12-09 19:28:49.608308      away    active      away      away
# 2  2020-12-09 19:28:56.343821      away    active      away      away
# 3  2020-12-09 19:29:03.022485      away    active      away      away
# 4  2020-12-09 19:29:09.784745      away    active      away      away
# 5  2020-12-09 19:29:16.957270      away    active      away      away
# 6  2020-12-09 19:29:23.813135      away    active      away      away
# 7  2020-12-09 19:29:30.611307      away    active      away      away
# 8  2020-12-09 19:29:37.324510      away    active      away      away
# 9  2020-12-09 19:29:44.708132      away      away      away      away
# 10 2020-12-09 19:29:52.739984      away      away      away      away
#
#    U01DN3G99HN
# 0         away
# 1         away
# 2         away
# 3         away
# 4         away
# 5         away
# 6         away
# 7         away
# 8         away
# 9         away
# 10        away

# %%
curr_status = new_df.loc[len(new_df)-1]
print(curr_status)
# Out:
# Time           2020-12-09 19:29:52.739984
# USLACKBOT                            away
# UFP3UKJ2G                            away
# UTASCHNN9                            away
# UTASDEA1K                            away
# U01DN3G99HN                          away
# Name: 10, dtype: object

# %%
print(new_df.loc[0])
# Out:
# Time           1.60751e+09
# USLACKBOT             away
# UFP3UKJ2G             away
# UTASCHNN9             away
# UTASDEA1K             away
# U01DN3G99HN           away
# Name: 0, dtype: object

# %%
d = {'k10': {'status': 'active', 'last_modified': 10}, 'k100': 100}
print(d['k10']['status'])
# Out:
# active

# %%
def capture():
    cap = cv2.VideoCapture(0)
    # cap.set(4, 320)
    n = 0
    no_face_for = 0
    hello_for = 0
    while True:
        # get 1frame
        ret, frame = cap.read()
        frame = imutils.resize(frame, width=320)
        # if no frame then close
        if (not ret):
            break
        if (n < 10):
            n += 1
            continue

        dets = face_detector(frame, 1)
        det_str = str(dets)
        # print(str(dets))
        date = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        # print(date)
        if (det_str == 'rectangles[]'):
            no_face_for += 1
            if no_face_for == 10:
                hello_for = 0
                print('no face')
                detected_inactive(date)
        else:
            hello_for += 1
            if hello_for == 10:
                no_face_for = 0
                print('hello face')
                detected_active(date)

        # show window
        cv2.imshow("Frame", frame)
        key = cv2.waitKey(1)
        # EscKey closes the program
        if key == 27:
            break
        n += 1

    cap.release()
    slack.change_status('', '')
    cv2.destroyAllWindows()


def detected_inactive(date):
    slack.send_message(
        "You are offline... [" + date + "]", "#imactive-response")
    slack.change_status('I am offline...', ':hear_no_evil:')


def detected_active(date):
    slack.send_message(
        "Hello, you are here! [" + date + "]", "#imactive-response")
    slack.change_status('Hi, I am available!', ':thumbsup:')

def create_object():
    pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d39f4e9e05d5> in <module>
#       1 breakpoint()
# ----> 2 def capture():
#       3     cap = cv2.VideoCapture(0)
#       4     # cap.set(4, 320)
#       5     n = 0
#
# <ipython-input-6-d39f4e9e05d5> in <module>
#       1 breakpoint()
# ----> 2 def capture():
#       3     cap = cv2.VideoCapture(0)
#       4     # cap.set(4, 320)
#       5     n = 0
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# ~/.vscode/extensions/ms-python.python-2020.11.371526539/pythonFiles/lib/python/debugpy/_vendored/pydevd/pydevd.py in do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    1853
#    1854             with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1855                 keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1856
#    1857         frames_list = None
#
# ~/.vscode/extensions/ms-python.python-2020.11.371526539/pythonFiles/lib/python/debugpy/_vendored/pydevd/pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1888
#    1889             self.process_internal_commands()
# -> 1890             time.sleep(0.01)
#    1891
#    1892         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %%
if __name__ == '__main__':
    slack = SlackDriver(slack_oauth_token, slack_user_token)
    # slack.send_button()
    member_list = slack.users_list()
    slack.track_presence(member_list)
# Out:
# ['Time', 'USLACKBOT', 'UFP3UKJ2G', 'UTASCHNN9', 'UTASDEA1K', 'U01DN3G99HN']
# [1607504126.195267, 'away', 'active', 'away', 'away', 'away']
# [1607504130.195267, 'away', 'active', 'away', 'away', 'away']
# [1607504134.195267, 'away', 'active', 'away', 'away', 'away']
# [1607504138.195267, 'away', 'active', 'away', 'away', 'away']
# [1607504142.195267, 'away', 'active', 'away', 'away', 'away']
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# Traceback (most recent call last):
#   File "/Users/kaedei/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-b91ae00aef50>", line 5, in <module>
#     slack.track_presence(member_list)
#   File "<ipython-input-3-840f417ae58d>", line 135, in track_presence
#     res_list.append(self.read_presence(member_id)['presence'])
#   File "<ipython-input-3-840f417ae58d>", line 94, in read_presence
#     r = requests.post('https://slack.com/api/users.getPresence',
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py", line 119, in post
#     return request('post', url, data=data, json=json, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py", line 520, in request
#     settings = self.merge_environment_settings(
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py", line 699, in merge_environment_settings
#     env_proxies = get_environ_proxies(url, no_proxy=no_proxy)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/utils.py", line 766, in get_environ_proxies
#     if should_bypass_proxies(url, no_proxy=no_proxy):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/utils.py", line 750, in should_bypass_proxies
#     bypass = proxy_bypass(parsed.hostname)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py", line 2646, in proxy_bypass
#     return proxy_bypass_macosx_sysconf(host)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py", line 2623, in proxy_bypass_macosx_sysconf
#     return _proxy_bypass_macosx_sysconf(host, proxy_settings)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py", line 2596, in _proxy_bypass_macosx_sysconf
#     hostIP = socket.gethostbyname(hostonly)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kaedei/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kaedei/Library/Python/3.8/lib/python/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kaedei/Library/Python/3.8/lib/python/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kaedei/Library/Python/3.8/lib/python/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/posixpath.py", line 424, in _joinrealpath
#     newpath = join(path, name)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/posixpath.py", line 77, in join
#     sep = _get_sep(a)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/posixpath.py", line 42, in _get_sep
#     if isinstance(path, bytes):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-5-b91ae00aef50> in <module>
#       4     member_list = slack.users_list()
# ----> 5     slack.track_presence(member_list)
#
# <ipython-input-3-840f417ae58d> in track_presence(self, member_list)
#     134                 for member_id in member_list:
# --> 135                     res_list.append(self.read_presence(member_id)['presence'])
#     136                     # print(res_list)
#
# <ipython-input-3-840f417ae58d> in read_presence(self, user)
#      93         params = {"token": self._user_token, "user":user}
# ---> 94         r = requests.post('https://slack.com/api/users.getPresence',
#      95                           headers=self._headers, params=params)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     519
# --> 520         settings = self.merge_environment_settings(
#     521             prep.url, proxies, stream, verify, cert
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in merge_environment_settings(self, url, proxies, stream, verify, cert)
#     698             no_proxy = proxies.get('no_proxy') if proxies is not None else None
# --> 699             env_proxies = get_environ_proxies(url, no_proxy=no_proxy)
#     700             for (k, v) in env_proxies.items():
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/utils.py in get_environ_proxies(url, no_proxy)
#     765     """
# --> 766     if should_bypass_proxies(url, no_proxy=no_proxy):
#     767         return {}
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/utils.py in should_bypass_proxies(url, no_proxy)
#     749         try:
# --> 750             bypass = proxy_bypass(parsed.hostname)
#     751         except (TypeError, socket.gaierror):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in proxy_bypass(host)
#    2645         else:
# -> 2646             return proxy_bypass_macosx_sysconf(host)
#    2647
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in proxy_bypass_macosx_sysconf(host)
#    2622         proxy_settings = _get_proxy_settings()
# -> 2623         return _proxy_bypass_macosx_sysconf(host, proxy_settings)
#    2624
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in _proxy_bypass_macosx_sysconf(host, proxy_settings)
#    2595                 try:
# -> 2596                     hostIP = socket.gethostbyname(hostonly)
#    2597                     hostIP = ip2num(hostIP)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/Library/Python/3.8/lib/python/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         stb = value._render_traceback_()
#    2045                     except Exception:
# -> 2046                         stb = self.InteractiveTB.structured_traceback(etype,
#    2047                                             value, tb, tb_offset=tb_offset)
#    2048
#
# ~/Library/Python/3.8/lib/python/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1433         else:
#    1434             self.tb = tb
# -> 1435         return FormattedTB.structured_traceback(
#    1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#
# ~/Library/Python/3.8/lib/python/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1333         if mode in self.verbose_modes:
#    1334             # Verbose modes need a full traceback
# -> 1335             return VerboseTB.structured_traceback(
#    1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#
# ~/Library/Python/3.8/lib/python/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1190         """Return a nice text document describing the traceback."""
#    1191
# -> 1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1193                                                                tb_offset)
#    1194
#
# ~/Library/Python/3.8/lib/python/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/Library/Python/3.8/lib/python/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
